# %% [markdown]
# # Homework Assignment 1
#
# ### Video Lectures:
# 1. [Google's Deep Mind Explained! - Self Learning A.I.](https://www.youtube.com/watch?v=TnUYcTuZJpM)
#
# 2. [Genetic algorithm. Learning to jump over ball.](https://www.youtube.com/watch?v=Gl3EjiVlz_4&t=65s) - Learning simple creature to jump over ball. This is an  animation demonstartion of the power of learning through Genetic Algorithm(GA).  It shows how GA and neural network(NN) can be combined for automated design of motion strategy.
#
# 3. [How we're teaching computers to understand pictures](https://www.ted.com/talks/fei_fei_li_how_we_re_teaching_computers_to_understand_pictures/up-next) by Fei-Fei Li, 2015 - When a very young child looks at a picture, she can identify simple elements: "cat," "book," "chair." Now, computers are getting smart enough to do that too. What's next? In a thrilling talk, computer vision expert Fei-Fei Li describes the state of the art -- including the database of 15 million photos her team built to "teach" a computer to understand pictures -- and the key insights yet to come.
#
# 4. [The wonderful and terrifying implications of computers that can learn](https://www.ted.com/talks/jeremy_howard_the_wonderful_and_terrifying_implications_of_computers_that_can_learn/up-next) by Jeremy Howard at TED 2014 - What happens when we teach a computer how to learn? Technologist Jeremy Howard shares some surprising new developments in the fast-moving field of deep learning, a technique that can give computers the ability to learn Chinese, or to recognize objects in photos, or to help think through a medical diagnosis. (One deep learning tool, after watching hours of YouTube, taught itself the concept of "cats.") Get caught up on a field that will change the way the computers around you behave ... sooner than you probably think.
#
# 5. [How computers learn to recognize objects instantly - YOLO](https://www.ted.com/talks/joseph_redmon_how_a_computer_learns_to_recognize_objects_instantly/up-next?referrer=playlist-what_are_we_really_teaching_ai) by Joseph Redmon at TED2017 - Ten years ago, researchers thought that getting a computer to tell the difference between a cat and a dog would be almost impossible. Today, computer vision systems do it with greater than 99 percent accuracy. How? Joseph Redmon works on the YOLO (You Only Look Once) system, an open-source method of object detection that can identify objects in images and video -- from zebras to stop signs -- with lightning-quick speed. In a remarkable live demo, Redmon shows off this important step forward for applications like self-driving cars, robotics and even cancer detection.
#
# 6. [What intelligent machines can learn from a school of fish](https://www.ted.com/talks/radhika_nagpal_what_intelligent_machines_can_learn_from_a_school_of_fish/up-next?referrer=playlist-what_are_we_really_teaching_ai&language=en) by Radhika Nagpal at TED2017 - Science fiction visions of the future show us AI built to replicate our way of thinking -- but what if we modeled it instead on the other kinds of intelligence found in nature? Robotics engineer Radhika Nagpal studies the collective intelligence displayed by insects and fish schools, seeking to understand their rules of engagement. In a visionary talk, she presents her work creating artificial collective power and previews a future where swarms of robots work together to build flood barriers, pollinate crops, monitor coral reefs and form constellations of satellites.
#
# 7. [The 7 Steps of Machine Learning(AI Adventures)](https://www.youtube.com/watch?v=nKW8Ndu7Mjw) - How can we tell if a drink is beer or wine? Machine learning, of course! In this episode of Cloud AI Adventures, Yufeng walks through the 7 steps involved in applied machine
# learning.
#
# ### 1. Group Assignment:
#
# As a group assignment, you pick up three videos listed above. After watching videos together, create three types of quizzes; true-false questions, multiple-choice question, and fill-in-the-blank questions. You should make three different type of questions for each video. This makes a total of nine questions and answers.
#
# When you post your questions and answers in jupyter notebook file, name your file with your group number and assignment number, for example, Group1-Assignment1.ipynb. In the file, you have the names of your group memebers. Questions are to be categorized by Video titles you chose from. Pay attention to your quality of questions and answers as a group of graduate students. Contents and their format will be graded as well.
#
#
# ### 2. Programming Assignment:
#
# 1. Watch the following two videos.
#     - [Hello World - Machine Learning Recipes](https://www.youtube.com/watch?v=cKxRvEZd3Mw) - This video uploaded by Google Developers. Six lines of Python is all it takes to write your first machine learning program! We'll follow a recipe for supervised learning (a technique to create a classifier from examples) and code it up.
#
#     - [Visualizing a Decision Tree ](https://www.youtube.com/watch?v=tNa99PG8hR8) - Build one on a real dataset, add code to visualize it, and practice reading it - so you can see how it works under the hood.
#
# 2. In one jupyter notebook, do coding for __Hello World__ and __Visualizing a Decision Tree__ presented in the video. Use Python3.x instead of Python 2.7 used in video. Post your work at Piazza by 24 hours before the next class. Have a reasonably good document of the program as you have seen in my lecture note.
#
#
# ### 3. Reading Assignment
#
# 1.	"Make your own neural network" by  Tariq Rashid - This book is available in e-book form from amazon.com.  It costs you a few dollars. You are expected to have a copy of the required textbook.
#
#     Part 1 - How They Work
#         - Easy for Me, Hard for You
#         - A Simple Predicting Machine
#         - Classifying is Not Very Different Predicting
#         - Training A Simple Classifier
#         - Sometimes One Classifier is not enough
#         - Neurons - Nature's Computing Machines
#
# 2. We take a turn to present some of homework assignments. This time, one of four group we have in our class will presents the material from this reading assignment for 30~40 minutes.

# %% [markdown]
# # Homework Assignment 2:
#
# ### 1. Group Assignment:
#
#
# 1. Recommend one of the best video lecture about ANN or Backpropagation from your group choose and summerize it for 10~15 miniute next class.
#
# 2. Modify Programming Assignment 1 to use 120 samples (40 samples each category) for training and 30 samples for test. Run the classifier and compute the accuracy.
#
#
# ### 2. Programming Assignment:
#
# 1. Watch the following three videos: `Machine Learning Recipes 3 ~ 5`. In one jupyter notebook, do coding for KMClassifer in Machine Learning Recipes 5 Video. Post your work at Piazza by 24 hours before the next class. Have a reasonably good document of the program as you have seen in my lecture note.
#
#
# ### 3. Reading Assignment for all
#
# 1.	"Make your own neural network" by  Tariq Rashid - This book is available in e-book form from amazon.com.  It costs you a few dollars. You are expected to have a copy of the required textbook.
#
#     Part 1 - How They Work
#         - Following Signals Through A Neural Network
#         - Matrix Multiplication is Useful.. Honest!
#         - A Three Layer Example with Matrix Multiplication
#         - Learning Weights From More Than One Node
#
# 2. We take a turn to present some of homework assignments. Group 2 will present the material from this reading assignment for 30~40 minutes in the next class.  Group 1 will also present the material from the first part of the book as well.

# %% [markdown]
# # Homework Assignment 3
#
# ### 1. Group Assignment:
#
# Watch Gordon's lecture `Machine Learning Recipes 6 ~ 7`. In one jupyter notebook, do coding for TFLearn or in Machine Learning Recipes 6 ~ 7 Video. Post your work at Piazza by 24 hours before the next class. Have a reasonably good document of the program as you have seen in my lecture note.
#
#     - Work with Tensorflow if possible
#     - Get familiar with MNIST Classification.
#     - Find the accuracy of each digit
#
#
# ### 2. Reading & Programming Assignment for all
#
# 1. __Required Part:__ Read Part 1 & 2 of "Make your own neural network" by  Tariq Rashid. Implement ANN for MNIST as implemented in the book. Post your work at Piazza by 12 hours before the next class. Have a reasonably good document of the program as you have seen in my lecture note.
#
# 2. __Optional Part:__ Use the original training and test dataset and Implement the following two challenge Problems.
#     - Find the number of samples of each digit in MNIST test and train dataset.
#     - Find the accuracy of each digit
#
# __For Group 4 only__ Group 4 will present the material from this reading assignment for 30~40 minutes in the next class.
#
# __For Group 5 only__ In the following class or the last class, Group 5 will work on the rest of the book (Part 3 - Even More Fun) such as recognizing your own handwritten digit, image rotation, and "Inside the Mind of a Neural Network".
#
#
# ### 3. NumPy Assignment Exercises
#
# Review NumPy lecture material and complete JoyQuizzes in the NumPyExercises.ipynb file. Post your work at Piazza by 12 hours before the next class. Have a reasonably good document of the program as you have seen in my lecture note.

# %% [markdown]
# # Final Report & Presentation
#
# For the last couple of weeks, we have studied how the machine learning works. We watched several excellent video lectures and even have programmed a few artificial neural network models in Python. Given this short introduction of the machine learning concepts, I would like to ask you to write a reflection paper and have a presentation in the final class.
#
# The purpose of this final report and presentation is to show that you understand the concepts of the machine learning and its applications. Hopefully, you find a related field of your work to apply for. It may be an introduction to the new field, a feasibility study or just to show the potentials of this technology.
#
# Remember that the purpose of this final assignment is to show your study result for a couple of weeks.  It would be a better choice if it is a concrete subject than a general topic.  Don't select the topic that anyone can do without the machine learning course. Do something to show what you have learned for a couple weeks if you can.  I am not necessarily saying that you must do "coding".  You may get the code from others or from Github if you go for with coding.  I am afraid that it would be more difficult to satisfy the purpose of this final assignment if you choose a general topic, but you may do it if you decided.
#
# - Post your report 12 hours before the final class, the presentation material itself may be turned in after the class. Use "final_exam" tag to post your material in Piazza.
# - You will have about 10 minutes for presentation in front of all classmates.
# - This report and presentation will be graded as one-third of the course grade.
#
# Blessings,
#
# (a debtor)<><
